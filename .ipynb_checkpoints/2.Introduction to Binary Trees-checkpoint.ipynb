# %% [markdown]
# In this file, we'll start learning how we can use recursion to define data structures. In particular, we're going to learn about **binary trees**.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# We call nodes that have both a parent and children **internal**. Nodes `4` and `9` are internal nodes.

# %% [markdown]
# We'll learn throughout why storing data in a tree data structure can yield much faster operations than using a list.
#
# Let's practice our understanding of these concepts by identifying the root node, the internal nodes, and the leaves of a given tree.

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
root = 5
leaves = [1, 6, 10]
internal = [3, 9, 8]

# %% [markdown]
# Above we learned some of the terminology of tree data structures. Now we'll start implementing a binary tree data structure.
#
# The first thing that we need to implement is a class to represent nodes. A node needs to store a value and its children.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
class Node:
    
    def __init__(self, value):
        self.value = value
        self.left_child = None
        self.right_child = None

# %% [markdown]
# Now, we'll use the Node implementation from the previous screen to create a binary tree.
#
# To help with this, we'll show how we would build the following tree:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# The `Node` class from above is still available. The goal of this exercise is to use it to create the binary tree shown in the following diagram:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
# Create the nodes
node_5 = Node(5)
node_3 = Node(3)
node_9 = Node(9)
node_1 = Node(1)
node_8 = Node(8)
node_6 = Node(6)
node_10 = Node(10)

# Create children references
node_5.left_child = node_3
node_5.right_child = node_9

node_3.left_child = node_1

node_9.left_child = node_8
node_9.right_child = node_10

node_8.left_child = node_6

# %% [markdown]
# Above we used the node class to manually build a specific tree. This was, to say the least, a bit cumbersome. Our goal now is to start implementing a class that uses the `Node` to automatically build the binary tree structure for us.

# %% [markdown]
# By the end of this file, we will be able to **add** and **lookup** values to the tree. When we add a new value the tree, it will automatically create a new node and place for it.
#
# But what is the right place for a value? Consider adding value `7` to the following binary tree:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
class BST:
    
    def __init__(self):
        self.root = None

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This process stops either when we want to go left but the current node doesn't have a left child or we want to go right and the current node doesn't have a right child.
#
# The following animation illustrates this process:

# %%
from IPython.display import Image
Image("5.1-m229.gif")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# `BST` class from above, we've added an `add()` method. This method checks whether the root is defined. If it isn't, it creates a new node with the given value.
#
# Otherwise, it will call the `add_recursive()` method to go down the tree and insert the value. Our goal is to implement the `add_recursive()` method.
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
class BST:
    
    def __init__(self):
        self.root = None
        
    def add(self, value):
        if self.root is None:
            # The root does exist yet, create it
            self.root = Node(value)
        else:
            # Find the right place and insert new value
            self.add_recursive(self.root, value)
            
    def add_recursive(self, current_node, value):
        if value <= current_node.value:
            # Go to the left
            if current_node.left_child is None:
                current_node.left_child = Node(value)
            else:
                self.add_recursive(current_node.left_child, value)
        else:
            # Go to the right
            if current_node.right_child is None:
                current_node.right_child = Node(value)
            else:
                self.add_recursive(current_node.right_child, value)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Image("6.1-m229.gif")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
class BST:
    
    def __init__(self):
        self.root = None
        
    def add(self, value):
        if self.root is None:
            # The root does exist yet, create it
            self.root = Node(value)
        else:
            # Find the right place and insert new value
            self.add_recursive(self.root, value)
            
    def add_recursive(self, current_node, value):
        if value <= current_node.value:
            # Go to the left
            if current_node.left_child is None:
                current_node.left_child = Node(value)
            else:
                self.add_recursive(current_node.left_child, value)
        else:
            # Go to the right
            if current_node.right_child is None:
                current_node.right_child = Node(value)
            else:
                self.add_recursive(current_node.right_child, value)
                
    def contains(self, current_node, value):
        if current_node is None:
            return False
        if current_node.value == value:
            return True
        if value < current_node.value:
            return self.contains(current_node.left_child, value)
        return self.contains(current_node.right_child, value)

# %% [markdown]
# Congratulations on implementing our first tree data structure! We now have a functional BST!
#
# Now we're going to discuss some improvements in the implementation to fix the following problems:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
class BST:
    
    def __init__(self):
        self.root = None
        
    def add(self, value):
        if self.root is None:
            # The root does exist yet, create it
            self.root = Node(value)
        else:
            # Find the right place and insert new value
            self._add_recursive(self.root, value)
            
    def _add_recursive(self, current_node, value):
        if value <= current_node.value:
            # Go to the left
            if current_node.left_child is None:
                current_node.left_child = Node(value)
            else:
                self._add_recursive(current_node.left_child, value)
        else:
            # Go to the right
            if current_node.right_child is None:
                current_node.right_child = Node(value)
            else:
                self._add_recursive(current_node.right_child, value)
                
    def _contains(self, current_node, value):
        if current_node is None:
            return False
        if current_node.value == value:
            return True
        if value < current_node.value:
            return self._contains(current_node.left_child, value)
        return self._contains(current_node.right_child, value)

    def contains(self, value):
        return self._contains(self.root, value)

# %% [markdown]
# With the improvements above, our BST implementation is much cleaner and easier to use. Users don't need to know the internal structure of the tree anymore.
#
# At the beginning of this file, we built the following tree by manually creating the nodes and assigning the children:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, we're going to create the same tree again but using the `add()` method this time. However, to get that exact tree, we can't insert the values in any order!
#
# For example, if we add the values in increasing order `[1, 3, 5, 6, 8, 9, 10]`, then we will instead get this:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Answer**

# %%
bst = BST()
for value in [5, 3, 9, 1, 8, 10, 6]:
    bst.add(value)

# %% [markdown]
# Let's discuss the advantages we get from using a BST instead of a list.
#
# The time it takes to add a value to a BST or check whether it contains a value depends on how tall the tree is. The **height** of a tree is the length of the longest path from the root to a leaf.
#
# Here are a few examples with the longest paths highlighted in blue on each example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In the next file, we'll learn how we can ensure that the complexity is logarithmic for any insertion order.
#
# In this file, we've defined and built a binary search tree and implemented insertion and lookups using recursion. We've learned that the complexity of these operations strongly depends on the height of the tree, which can be anywhere from logarithmic to linear.
#
# For the next file, we'll extend the BST implementation to ensure that the height of the tree remains logarithmic regardless of the order in which values are inserted.
